# %% [markdown]
# # Netflix Exploratory Data Analysis (EDA) using NumPy and Pandas
#
# **Author:** Altamash
#
# ## Project Objective
#
# This project performs complete Exploratory Data Analysis (EDA) on the Netflix
# Movies and TV Shows dataset using NumPy, Pandas, and Matplotlib.
# ### Goals
#
# - Understand dataset structure.
# - Clean missing and inconsistent data.
# - Perform statistical analysis using NumPy.
# - Analyze Netflix content using Pandas.
# - Create business insights and visualizations.

# %%
# ==========================================
# Import Required Libraries
# ==========================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Notebook display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 20)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## Load Netflix Dataset
#
# The dataset is loaded from the data folder into a Pandas DataFrame.

# %%
# ==========================================
# Load Dataset
# ==========================================

df = pd.read_csv("../data/netflix_titles.csv")

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
# Dataset Shape

df.shape
# Out:
# (8807, 12)

# %%
#Display the first five records.
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
#List all feature names available in the dataset.

df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Count rows and columns separately.

print("numbers of rows : ",df.shape[0])
print("numbers of columns : ",df.shape[1])
# Out:
# numbers of rows :  8807
# numbers of columns :  12

# %% [markdown]
# ## Dataset Information
#
# Understand data types, missing values, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## Statistical Summary
#
# Generate summary statistics for numerical columns.

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ## Categorical Summary
#
# Explore object-type columns.

# %%
df.describe(include="object")
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# ## Data Types
#
# Check data type of each feature.

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ### Observation
#
# date_added should be converted from object to datetime during data cleaning.

# %% [markdown]
# ## Memory Usage
#
# Check memory consumed by each column.

# %%
memory_usage = df.memory_usage(deep=True)

memory_usage
# Out:
# Index               132
# show_id          474471
# type             480930
# title            593151
# director         488185
# cast            1422387
# country          517757
# date_added       561028
# release_year      70456
# rating           470514
# duration         493486
# listed_in        725748
# description     1873527
# dtype: int64

# %%
total_memory = memory_usage.sum() / (1024**2)

print(f"Total Memory Usage: {total_memory:.2f} MB")
# Out:
# Total Memory Usage: 7.79 MB

# %% [markdown]
# ## Frequency Analysis
#
# Count Movies and TV Shows.

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df["type"].value_counts(normalize=True) * 100
# Out:
# type
# Movie      69.615079
# TV Show    30.384921
# Name: proportion, dtype: float64

# %% [markdown]
# ## Unique Value Analysis

# %%
df["country"].nunique()
# Out:
# 748

# %%
df["country"].unique()[:10]
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia'], dtype=object)

# %% [markdown]
# ## EDA Summary Table
#
# Create a compact summary containing data type, missing values, and unique values.

# %%
summary = pd.DataFrame({
    "Data Type": df.dtypes,
    "Missing Values": df.isnull().sum(),
    "Unique Values": df.nunique()
})

summary
# Out:
#              Data Type  Missing Values  Unique Values
# show_id         object               0           8807
# type            object               0              2
# title           object               0           8807
# director        object            2634           4528
# cast            object             825           7692
# country         object             831            748
# date_added      object              10           1767
# release_year     int64               0             74
# rating          object               4             17
# duration        object               3            220
# listed_in       object               0            514
# description     object               0           8775

# %% [markdown]
# ## Initial Findings
#
# ### Key Observations
#
# - The dataset contains 8,807 Netflix titles.
# - There are 12 features describing each title.
# - type contains two categories: Movies and TV Shows.
# - date_added is stored as an object and requires datetime conversion.
# - director, cast, and country contain missing values.
# - Both numerical and categorical columns are present, requiring different analysis approaches.

# %% [markdown]
# # Missing Value Analysis
#
# Before performing analysis, we need to identify missing values in every feature.
# Missing values can affect statistics, visualizations, and machine learning models.

# %%
# Missing values in each column

df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Percentage of missing values

missing_percentage = (
    df.isnull().sum() / len(df)
) * 100

missing_percentage.sort_values(ascending=False)
# Out:
# director        29.908028
# country          9.435676
# cast             9.367549
# date_added       0.113546
# rating           0.045418
# duration         0.034064
# show_id          0.000000
# type             0.000000
# title            0.000000
# release_year     0.000000
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
# Missing Value Report

missing_report = pd.DataFrame({
    "Missing Count": df.isnull().sum(),
    "Missing Percentage": missing_percentage.round(2)
})

missing_report = missing_report.sort_values(
    by="Missing Percentage",
    ascending=False
)

missing_report
# Out:
#               Missing Count  Missing Percentage
# director               2634               29.91
# country                 831                9.44
# cast                    825                9.37
# date_added               10                0.11
# rating                    4                0.05
# duration                  3                0.03
# show_id                   0                0.00
# type                      0                0.00
# title                     0                0.00
# release_year              0                0.00
# listed_in                 0                0.00
# description               0                0.00

# %%
# Fill missing values

df["director"] = df["director"].fillna("Unknown")

df["cast"] = df["cast"].fillna("Not Available")

df["country"] = df["country"].fillna("Unknown")

# Fill rating using mode
df["rating"] = df["rating"].fillna(df["rating"].mode()[0])

# Fill duration using mode
df["duration"] = df["duration"].fillna(df["duration"].mode()[0])

# %%
# Remove rows where date_added is missing

df = df.dropna(subset=["date_added"])

# %%
# Verify cleaning

df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.shape
# Out:
# (8797, 12)

# %% [markdown]
# # Duplicate Analysis
#
# Duplicate records can distort frequency analysis and business insights.

# %%
# Count duplicate rows

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Rename Columns
#
# Use consistent naming conventions for readability and production-quality code.

# %%
# Rename columns

df.rename(columns={
    "type": "content_type",
    "listed_in": "genre"
}, inplace=True)

# %%
df.columns
# Out:
# Index(['show_id', 'content_type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'genre',
#        'description'],
#       dtype='object')

# %% [markdown]
# # Date Conversion
#
# Convert the date_added column from string to datetime format.

# %%
type(df["date_added"][0])
# Out:
# str

# %%
df["date_added"][0]
# Out:
# 'September 25, 2021'

# %%
# Remove leading/trailing spaces
df["date_added"] = df["date_added"].str.strip()

# Convert string to datetime
df["date_added"] = pd.to_datetime(
    df["date_added"],
    format="%B %d, %Y",
    errors="coerce"
)

# %%
df["date_added"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # Feature Engineering from Dates
#
# Extract useful temporal features from date_added.

# %%
# Create new features

df["year_added"] = df["date_added"].dt.year

df["month_added"] = df["date_added"].dt.month

df["month_name"] = df["date_added"].dt.month_name()

df["day_added"] = df["date_added"].dt.day

# %%
df[[
    "date_added",
    "year_added",
    "month_added",
    "month_name",
    "day_added"
]].head()
# Out:
#   date_added  year_added  month_added month_name  day_added
# 0 2021-09-25        2021            9  September         25
# 1 2021-09-24        2021            9  September         24
# 2 2021-09-24        2021            9  September         24
# 3 2021-09-24        2021            9  September         24
# 4 2021-09-24        2021            9  September         24

# %%
df.sample(3)
# Out:
#      show_id content_type              title     director  \
# 8672   s8673        Movie  Veerey Ki Wedding  Ashu Trikha
# 4678   s4679      TV Show     Undercover Law      Unknown
# 1306   s1307      TV Show         Good Girls      Unknown
#
#                                                    cast        country  \
# 8672  Pulkit Samrat, Yuvika Chaudhry, Jimmy Shergill...          India
# 4678  Viña Machado, Juana del Río, Luna Baxter, Vale...       Colombia
# 1306  Christina Hendricks, Retta, Mae Whitman, Matth...  United States
#
#      date_added  release_year rating   duration  \
# 8672 2019-12-31          2018  TV-14    130 min
# 4678 2018-08-31          2017  TV-MA   1 Season
# 1306 2021-02-16          2020  TV-MA  3 Seasons
#
#                                                   genre  \
# 8672             Comedies, Dramas, International Movies
# 4678  Crime TV Shows, International TV Shows, Spanis...
# 1306             Crime TV Shows, TV Comedies, TV Dramas
#
# ...

# %% [markdown]
# # Remove Extra Spaces
#
# Text columns often contain unwanted leading or trailing spaces.

# %%
# Remove spaces

text_columns = [
    "title",
    "director",
    "cast",
    "country",
    "rating",
    "duration",
    "genre"
]

for column in text_columns:
    df[column] = df[column].str.strip()

# %% [markdown]
# # Standardize Category Values

# %%
df["rating"].value_counts()
# Out:
# rating
# TV-MA       3209
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# # Clean Duration Column
#
# Movies contain minutes.
# TV Shows contain seasons.
#
# We extract numerical duration separately.

# %%
# Extract numeric duration

df["duration_numeric"] = (
    df["duration"]
      .str.extract(r"(\d+)")
      .astype(int)
)

# %%
df[["duration", "duration_numeric"]].head()
# Out:
#     duration  duration_numeric
# 0     90 min                90
# 1  2 Seasons                 2
# 2   1 Season                 1
# 3   1 Season                 1
# 4  2 Seasons                 2

# %% [markdown]
# # Separate Movies and TV Shows
#
# Create filtered datasets for independent analysis.

# %%
movies_df = df[df["content_type"] == "Movie"]

tvshows_df = df[df["content_type"] == "TV Show"]

# %%
print("Movies :", movies_df.shape)
print("TV Shows :", tvshows_df.shape)
# Out:
# Movies : (6131, 17)
# TV Shows : (2666, 17)

# %% [markdown]
# # Validate Clean Dataset
#
# Run final checks after cleaning.

# %%
print("Remaining Missing Values")
print(df.isnull().sum())

print("\nDuplicate Rows")
print(df.duplicated().sum())

print("\nDataset Shape")
print(df.shape)
# Out:
# Remaining Missing Values
# show_id             0
# content_type        0
# title               0
# director            0
# cast                0
# country             0
# date_added          0
# release_year        0
# rating              0
# duration            0
# genre               0
# description         0
# year_added          0
# month_added         0
# month_name          0
# day_added           0
# duration_numeric    0
# dtype: int64
#
# Duplicate Rows
# 0
#
# Dataset Shape
# (8797, 17)

# %%
cleaning_summary = pd.DataFrame({
    "Metric": [
        "Rows",
        "Columns",
        "Duplicate Rows Removed",
        "Missing Values Remaining"
    ],
    "Value": [
        len(df),
        df.shape[1],
        0,
        df.isnull().sum().sum()
    ]
})

cleaning_summary
# Out:
#                      Metric  Value
# 0                      Rows   8797
# 1                   Columns     17
# 2    Duplicate Rows Removed      0
# 3  Missing Values Remaining      0

# %% [markdown]
# ## Cleaning Summary
#
# ### Completed Cleaning Steps
#
# - Missing values handled using fill and drop strategies.
# - Duplicate rows removed.
# - Column names standardized.
# - date_added converted to datetime.
# - Extra spaces removed from text columns.
# - Numerical duration extracted from text.
# - New temporal features created (year_added, month_added, month_name, day_added).
#
# The dataset is now ready for statistical analysis and visualization.

# %% [markdown]
# # Convert Pandas Columns to NumPy Arrays
#
# NumPy performs mathematical operations on arrays faster than Python lists and is widely used in Machine Learning libraries.

# %%
# Convert columns into NumPy arrays

release_year_array = df["release_year"].to_numpy()
duration_array = df["duration_numeric"].to_numpy()

# %%
print(type(release_year_array))
print(type(duration_array))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Mean of Release Year
#
# Mean gives the average release year of Netflix content.

# %%
mean_release_year = np.mean(release_year_array)
mean_duration = np.mean(duration_array)

print("Average Release Year :", round(mean_release_year, 2))
print("Average Duration :", round(mean_duration, 2))
# Out:
# Average Release Year : 2014.18
# Average Duration : 69.9

# %% [markdown]
# ## Median of Release Year
#
# Median represents the middle value after sorting the data.

# %%
median_release_year = np.median(release_year_array)
median_duration = np.median(duration_array)

print("Median Release Year :", median_release_year)
print("Median Duration :", median_duration)
# Out:
# Median Release Year : 2017.0
# Median Duration : 88.0

# %% [markdown]
# ## Mode of Rating
#
# Mode is the most frequently occurring value.

# %%
mode_rating = df["rating"].mode()[0]

print("Most Common Rating :", mode_rating)
# Out:
# Most Common Rating : TV-MA

# %% [markdown]
# ## Minimum and Maximum Values
#
# Find oldest and newest release years and shortest/longest durations.

# %%
print("Oldest Release Year :", np.min(release_year_array))
print("Newest Release Year :", np.max(release_year_array))

print("Shortest Duration :", np.min(duration_array))
print("Longest Duration :", np.max(duration_array))
# Out:
# Oldest Release Year : 1925
# Newest Release Year : 2021
# Shortest Duration : 1
# Longest Duration : 312

# %% [markdown]
# ## Range
#
# Range measures spread between maximum and minimum values.

# %%
release_range = np.max(release_year_array) - np.min(release_year_array)
duration_range = np.max(duration_array) - np.min(duration_array)

print("Release Year Range :", release_range)
print("Duration Range :", duration_range)
# Out:
# Release Year Range : 96
# Duration Range : 311

# %% [markdown]
# ## Variance
#
# Variance measures how far values are spread from the mean.

# %%
release_variance = np.var(release_year_array)
duration_variance = np.var(duration_array)

print("Variance (Release Year):", round(release_variance, 2))
print("Variance (Duration):", round(duration_variance, 2))
# Out:
# Variance (Release Year): 77.82
# Variance (Duration): 2580.78

# %% [markdown]
# ## Standard Deviation
#
# Standard deviation is the square root of variance.

# %%
release_std = np.std(release_year_array)
duration_std = np.std(duration_array)

print("Standard Deviation (Release Year):", round(release_std, 2))
print("Standard Deviation (Duration):", round(duration_std, 2))
# Out:
# Standard Deviation (Release Year): 8.82
# Standard Deviation (Duration): 50.8

# %% [markdown]
# ## Percentile Analysis
#
# Percentiles help understand data distribution.

# %%
percentiles = np.percentile(
    duration_array,
    [25, 50, 75, 90, 95]
)

print(percentiles)
# Out:
# [  2.  88. 106. 126. 139.]

# %%
#Quartiles individually

q1 = np.percentile(duration_array, 25)
q2 = np.percentile(duration_array, 50)
q3 = np.percentile(duration_array, 75)

print("Q1 :", q1)
print("Q2 :", q2)
print("Q3 :", q3)
# Out:
# Q1 : 2.0
# Q2 : 88.0
# Q3 : 106.0

# %% [markdown]
# ## Interquartile Range (IQR)
#
# IQR measures the spread of the middle 50% of the data.

# %%
iqr = q3 - q1

print("Interquartile Range :", iqr)
# Out:
# Interquartile Range : 104.0

# %% [markdown]
# ## Outlier Detection Using IQR

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = df[
    (df["duration_numeric"] < lower_bound) |
    (df["duration_numeric"] > upper_bound)
]

outliers.head()
# Out:
#      show_id content_type                        title director  \
# 717     s718        Movie  Headspace: Unwind Your Mind  Unknown
# 4253   s4254        Movie   Black Mirror: Bandersnatch  Unknown
#
#                                                    cast        country  \
# 717   Andy Puddicombe, Evelyn Lewis Prieto, Ginger D...        Unknown
# 4253  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#      date_added  release_year rating duration  \
# 717  2021-06-15          2021   TV-G  273 min
# 4253 2018-12-28          2018  TV-MA  312 min
#
#                                                genre  \
# 717                                    Documentaries
# 4253  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                             description  year_added  \
# 717   Do you want to relax, meditate or sleep deeply...        2021
# 4253  In 1984, a young programmer begins to question...        2018
#
# ...

# %% [markdown]
# ## NumPy Statistical Summary

# %%
statistics_summary = pd.DataFrame({
    "Metric": [
        "Mean",
        "Median",
        "Minimum",
        "Maximum",
        "Variance",
        "Standard Deviation"
    ],
    "Release Year": [
        np.mean(release_year_array),
        np.median(release_year_array),
        np.min(release_year_array),
        np.max(release_year_array),
        np.var(release_year_array),
        np.std(release_year_array)
    ],
    "Duration": [
        np.mean(duration_array),
        np.median(duration_array),
        np.min(duration_array),
        np.max(duration_array),
        np.var(duration_array),
        np.std(duration_array)
    ]
})

statistics_summary.round(2)
# Out:
#                Metric  Release Year  Duration
# 0                Mean       2014.18     69.90
# 1              Median       2017.00     88.00
# 2             Minimum       1925.00      1.00
# 3             Maximum       2021.00    312.00
# 4            Variance         77.82   2580.78
# 5  Standard Deviation          8.82     50.80

# %% [markdown]
# ## Statistical Observations
#
# ### Key Findings
#
# - Netflix content is primarily composed of relatively recent releases.
# - Movie and TV Show durations vary significantly.
# - The duration column contains outliers that can be analyzed separately.
# - Median duration is more representative than mean because duration distribution is skewed.
# - The IQR method identifies unusually long-duration content.

# %% [markdown]
# # Frequency Analysis using value_counts()
#
# Identify the frequency of categorical values in the dataset.

# %%
# Count Movies and TV Shows

df["content_type"].value_counts()
# Out:
# content_type
# Movie      6131
# TV Show    2666
# Name: count, dtype: int64

# %%
content_percentage = (
    df["content_type"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

content_percentage
# Out:
# content_type
# Movie      69.69
# TV Show    30.31
# Name: proportion, dtype: float64

# %% [markdown]
# ### Insight
#
# Approximately 70% of Netflix content consists of Movies, while 30% consists of TV Shows.

# %% [markdown]
# # Most Common Ratings
#
# Understand Netflix's content maturity distribution.

# %%
rating_counts = (
    df["rating"]
    .value_counts()
)

rating_counts
# Out:
# rating
# TV-MA       3209
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
rating_counts.head(10)
# Out:
# rating
# TV-MA    3209
# TV-14    2157
# TV-PG     861
# R         799
# PG-13     490
# TV-Y7     333
# TV-Y      306
# PG        287
# TV-G      220
# NR         79
# Name: count, dtype: int64

# %% [markdown]
# # Unique Value Analysis

# %%
# Number of unique countries

df["country"].nunique()
# Out:
# 749

# %%
# Display first 15 unique countries

df["country"].unique()[:15]
# Out:
# array(['United States', 'South Africa', 'Unknown', 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria'], dtype=object)

# %% [markdown]
# # Sorting Data

# %%
latest_content = df.sort_values(
    by="release_year",
    ascending=False
)

latest_content.head()
# Out:
#     show_id content_type                                  title  \
# 693    s694        Movie                 Ali & Ratu Ratu Queens
# 781    s782        Movie  Black Holes | The Edge of All We Know
# 762    s763        Movie                           Sweet & Sour
# 763    s764      TV Show                            Sweet Tooth
# 764    s765        Movie           Trippin' with the Kandasamys
#
#            director                                               cast  \
# 693  Lucky Kuswandi  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...
# 781   Peter Galison                                      Not Available
# 762   Lee Kae-byeok          Jang Ki-yong, Chae Soo-bin, Jung Soo-jung
# 763         Unknown  Nonso Anozie, Christian Convery, Adeel Akhtar,...
# 764   Jayan Moodley  Jailoshini Naidoo, Maeshni Naicker, Madhushan ...
#
#            country date_added  release_year rating  duration  \
# 693        Unknown 2021-06-17          2021  TV-14   101 min
# ...

# %%
oldest_content = df.sort_values(
    by="release_year"
)

oldest_content.head()
# Out:
#      show_id content_type                               title  \
# 4250   s4251      TV Show   Pioneers: First Women Filmmakers*
# 7790   s7791        Movie                      Prelude to War
# 8205   s8206        Movie                The Battle of Midway
# 8739   s8740        Movie  Why We Fight: The Battle of Russia
# 8763   s8764        Movie     WWII: Report from the Aleutians
#
#                          director                       cast        country  \
# 4250                      Unknown              Not Available        Unknown
# 7790                  Frank Capra              Not Available  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8739  Frank Capra, Anatole Litvak              Not Available  United States
# 8763                  John Huston              Not Available  United States
#
#      date_added  release_year rating  duration                          genre  \
# ...

# %%
df.sort_values(
    by=["release_year", "title"],
    ascending=[False, True]
).head()
# Out:
#      show_id content_type                            title  \
# 1373   s1374      TV Show                             50M2
# 1150   s1151        Movie  7 Yards: The Chris Norton Story
# 850     s851        Movie                         99 Songs
# 851     s852        Movie                 99 Songs (Tamil)
# 852     s853        Movie                99 Songs (Telugu)
#
#                      director  \
# 1373                  Unknown
# 1150            Jonathon Link
# 850   Vishwesh Krishnamoorthy
# 851                   Unknown
# 852                   Unknown
#
#                                                    cast        country  \
# 1373  Engin Öztürk, Kürşat Alnıaçık, Cengiz Bozkurt,...         Turkey
# 1150                                       Chris Norton  United States
# 850   Ehan Bhat, Edilsy Vargas, Manisha Koirala, Lis...          India
# 851                                       Not Available        Unknown
# ...

# %% [markdown]
# # loc vs iloc
#
# Select rows and columns using labels and positions.

# %%
df.loc[0]
# Out:
# show_id                                                            s1
# content_type                                                    Movie
# title                                            Dick Johnson Is Dead
# director                                              Kirsten Johnson
# cast                                                    Not Available
# country                                                 United States
# date_added                                        2021-09-25 00:00:00
# release_year                                                     2020
# rating                                                          PG-13
# duration                                                       90 min
# genre                                                   Documentaries
# description         As her father nears the end of his life, filmm...
# year_added                                                       2021
# ...

# %%
#Select Specific Columns

df.loc[
    0:4,
    ["title", "country", "release_year"]
]
# Out:
#                    title        country  release_year
# 0   Dick Johnson Is Dead  United States          2020
# 1          Blood & Water   South Africa          2021
# 2              Ganglands        Unknown          2021
# 3  Jailbirds New Orleans        Unknown          2021
# 4           Kota Factory          India          2021

# %%
#Filter Using loc
df.loc[
    df["release_year"] >= 2020,
    ["title", "release_year", "country"]
].head()
# Out:
#                    title  release_year        country
# 0   Dick Johnson Is Dead          2020  United States
# 1          Blood & Water          2021   South Africa
# 2              Ganglands          2021        Unknown
# 3  Jailbirds New Orleans          2021        Unknown
# 4           Kota Factory          2021          India

# %%
#iloc — Position Based

df.iloc[0]
# Out:
# show_id                                                            s1
# content_type                                                    Movie
# title                                            Dick Johnson Is Dead
# director                                              Kirsten Johnson
# cast                                                    Not Available
# country                                                 United States
# date_added                                        2021-09-25 00:00:00
# release_year                                                     2020
# rating                                                          PG-13
# duration                                                       90 min
# genre                                                   Documentaries
# description         As her father nears the end of his life, filmm...
# year_added                                                       2021
# ...

# %%
#Rows and Columns by Position

df.iloc[
    0:5,
    1:5
]
# Out:
#   content_type                  title         director  \
# 0        Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      TV Show          Blood & Water          Unknown
# 2      TV Show              Ganglands  Julien Leclercq
# 3      TV Show  Jailbirds New Orleans          Unknown
# 4      TV Show           Kota Factory          Unknown
#
#                                                 cast
# 0                                      Not Available
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                      Not Available
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...

# %% [markdown]
# # Filtering Rows

# %%
#Movies Only

movies = df[
    df["content_type"] == "Movie"
]

movies.head()
# Out:
#    show_id content_type                             title  \
# 0       s1        Movie              Dick Johnson Is Dead
# 6       s7        Movie  My Little Pony: A New Generation
# 7       s8        Movie                           Sankofa
# 9      s10        Movie                      The Starling
# 12     s13        Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                       Not Available
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country date_added  \
# ...

# %%
#TV Shows Only

tv_shows = df[
    df["content_type"] == "TV Show"
]

tv_shows.head()
# Out:
#   show_id content_type                  title         director  \
# 1      s2      TV Show          Blood & Water          Unknown
# 2      s3      TV Show              Ganglands  Julien Leclercq
# 3      s4      TV Show  Jailbirds New Orleans          Unknown
# 4      s5      TV Show           Kota Factory          Unknown
# 5      s6      TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country date_added  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa 2021-09-24
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...       Unknown 2021-09-24
# 3                                      Not Available       Unknown 2021-09-24
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...       Unknown 2021-09-24
#
#    release_year rating   duration  \
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# ...

# %%
#Movies Released After 2020

recent_movies = df[
    (df["content_type"] == "Movie") &
    (df["release_year"] >= 2020)
]

recent_movies.head()
# Out:
#    show_id content_type                             title  \
# 0       s1        Movie              Dick Johnson Is Dead
# 6       s7        Movie  My Little Pony: A New Generation
# 9      s10        Movie                      The Starling
# 12     s13        Movie                      Je Suis Karl
# 13     s14        Movie  Confessions of an Invisible Girl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 9                  Theodore Melfi
# 12            Christian Schwochow
# 13                  Bruno Garotti
#
#                                                  cast  \
# 0                                       Not Available
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
#
# ...

# %%
#OR Condition (|)

india_or_usa = df[
    (df["country"] == "India") |
    (df["country"] == "United States")
]

india_or_usa.head()
# Out:
#    show_id content_type                 title         director  \
# 0       s1        Movie  Dick Johnson Is Dead  Kirsten Johnson
# 4       s5      TV Show          Kota Factory          Unknown
# 9      s10        Movie          The Starling   Theodore Melfi
# 15     s16      TV Show     Dear White People          Unknown
# 24     s25        Movie                 Jeans       S. Shankar
#
#                                                  cast        country  \
# 0                                       Not Available  United States
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...  United States
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...          India
#
#    date_added  release_year rating   duration  \
# 0  2021-09-25          2020  PG-13     90 min
# 4  2021-09-24          2021  TV-MA  2 Seasons
# ...

# %%
#Using isin()
#Multiple Countries

countries = ["India", "United States", "United Kingdom"]

df[
    df["country"].isin(countries)
].head()
# Out:
#    show_id content_type                          title         director  \
# 0       s1        Movie           Dick Johnson Is Dead  Kirsten Johnson
# 4       s5      TV Show                   Kota Factory          Unknown
# 8       s9      TV Show  The Great British Baking Show  Andy Devonshire
# 9      s10        Movie                   The Starling   Theodore Melfi
# 15     s16      TV Show              Dear White People          Unknown
#
#                                                  cast         country  \
# 0                                       Not Available   United States
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...           India
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...   United States
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...   United States
#
#    date_added  release_year rating   duration  \
# 0  2021-09-25          2020  PG-13     90 min
# ...

# %%
#NOT Condition (~)
#Non-Indian Content

non_indian = df[
    ~df["country"].isin(["India"])
]

non_indian.head()
# Out:
#   show_id content_type                  title         director  \
# 0      s1        Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2      TV Show          Blood & Water          Unknown
# 2      s3      TV Show              Ganglands  Julien Leclercq
# 3      s4      TV Show  Jailbirds New Orleans          Unknown
# 5      s6      TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                      Not Available        Unknown
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...        Unknown
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # GroupBy Analysis
#
# Group data by categories to generate business insights.

# %%
#Movies vs TV Shows Count

df.groupby("content_type").count()["show_id"]
# Out:
# content_type
# Movie      6131
# TV Show    2666
# Name: show_id, dtype: int64

# %%
#Content Added Each Year

yearly_content = (
    df.groupby("year_added")
    .size()
    .sort_values(ascending=False)
)

yearly_content.head(10)
# Out:
# year_added
# 2019    2016
# 2020    1879
# 2018    1649
# 2021    1498
# 2017    1188
# 2016     429
# 2015      82
# 2014      24
# 2011      13
# 2013      11
# dtype: int64

# %%
#Top Countries

top_countries = (
    df.groupby("country")
      .size()
      .sort_values(ascending=False)
      .head(10)
)

top_countries
# Out:
# country
# United States     2812
# India              972
# Unknown            830
# United Kingdom     418
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# dtype: int64

# %%
#Top Genres

top_genres = (
    df.groupby("genre")
      .size()
      .sort_values(ascending=False)
      .head(10)
)

top_genres
# Out:
# genre
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            219
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# dtype: int64

# %%
#Average Release Year by Content Type

df.groupby("content_type")["release_year"].mean()
# Out:
# content_type
# Movie      2013.121514
# TV Show    2016.625656
# Name: release_year, dtype: float64

# %% [markdown]
# # Aggregation with agg()
#
# Calculate multiple statistics simultaneously.

# %%
year_statistics = (
    df.groupby("year_added")
      .agg(
          total_titles=("show_id", "count"),
          average_release_year=("release_year", "mean"),
          oldest_release=("release_year", "min"),
          newest_release=("release_year", "max")
      )
)

year_statistics.head()
# Out:
#             total_titles  average_release_year  oldest_release  newest_release
# year_added
# 2008                   2           2006.500000            2006            2007
# 2009                   2           2008.000000            2007            2009
# 2010                   1           1987.000000            1987            1987
# 2011                  13           1991.076923            1986            2010
# 2012                   3           2011.000000            2010            2012

# %% [markdown]
# # String Operations

# %%
#Find Movies Containing "Love"

love_movies = df[
    df["title"].str.contains("Love", case=False, na=False)
]

love_movies.head()
# Out:
#     show_id content_type                      title               director  \
# 25      s26      TV Show       Love on the Spectrum                Unknown
# 158    s159        Movie    Love Don't Cost a Thing              Troy Byer
# 159    s160        Movie             Love in a Puff         Pang Ho-cheung
# 206    s207        Movie  LSD: Love, Sex Aur Dhokha       Dibakar Banerjee
# 227    s228        Movie                Really Love  Angel Kristi Williams
#
#                                                   cast        country  \
# 25                                    Brooke Satchwell      Australia
# 158  Nick Cannon, Christina Milian, Kenan Thompson,...  United States
# 159  Miriam Chin Wah Yeung, Shawn Yue, Singh Hartih...      Hong Kong
# 206  Nushrat Bharucha, Anshuman Jha, Neha Chauhan, ...          India
# 227  Kofi Siriboe, Yootha Wong-Loi-Sing, Michael Ea...  United States
#
#     date_added  release_year rating   duration  \
# ...

# %%
#Count Horror Content

horror_titles = df[
    df["genre"].str.contains("Horror", case=False, na=False)
]

len(horror_titles)
# Out:
# 432

# %% [markdown]
# # Country-wise Analysis

# %%
#Indian Content

india_content = df[
    df["country"].str.contains("India", na=False)
]

india_content.head()
# Out:
#    show_id content_type          title        director  \
# 4       s5      TV Show   Kota Factory         Unknown
# 24     s25        Movie          Jeans      S. Shankar
# 29     s30        Movie       Paranoia  Robert Luketic
# 39     s40      TV Show   Chhota Bheem         Unknown
# 50     s51      TV Show  Dharmakshetra         Unknown
#
#                                                  cast  \
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 29  Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# 50  Kashmira Irani, Chandan Anand, Dinesh Mehta, A...
#
#                          country date_added  release_year rating   duration  \
# 4                          India 2021-09-24          2021  TV-MA  2 Seasons
# 24                         India 2021-09-21          1998  TV-14    166 min
# ...

# %%
# Count Indian Movies vs TV Shows

india_content["content_type"].value_counts()
# Out:
# content_type
# Movie      962
# TV Show     84
# Name: count, dtype: int64

# %%
#USA Content

usa_content = df[
    df["country"].str.contains("United States", na=False)
]

usa_content["content_type"].value_counts()
# Out:
# content_type
# Movie      2752
# TV Show     932
# Name: count, dtype: int64

# %% [markdown]
# # Business Summary Tables

# %%
country_analysis = (
    df.groupby("country")
      .size()
      .reset_index(name="Total Content")
      .sort_values(
          by="Total Content",
          ascending=False
      )
)

country_analysis.head(10)
# Out:
#             country  Total Content
# 603   United States           2812
# 251           India            972
# 736         Unknown            830
# 506  United Kingdom            418
# 319           Japan            244
# 435     South Korea            199
# 58           Canada            181
# 444           Spain            145
# 162          France            124
# 342          Mexico            110

# %%
#Top Years Table

year_analysis = (
    df.groupby("year_added")
      .size()
      .reset_index(name="Titles Added")
      .sort_values(
          by="Titles Added",
          ascending=False
      )
)

year_analysis.head()
# Out:
#     year_added  Titles Added
# 11        2019          2016
# 12        2020          1879
# 10        2018          1649
# 13        2021          1498
# 9         2017          1188

# %%
#Save for Outputs Folder

country_analysis.to_csv(
    "../outputs/country_analysis.csv",
    index=False
)

year_analysis.to_csv(
    "../outputs/yearly_content.csv",
    index=False
)

# %% [markdown]
# # Pandas EDA Observations
#
# ### Key Findings
#
# - Movies dominate Netflix's catalog.
# - Content additions peaked during specific years.
# - The United States contributes the largest amount of content.
# - India is among the top content-producing countries.
# - TV-MA is the most frequent maturity rating.
# - Drama and International Movies are among the most common genres.

# %%
import matplotlib.pyplot as plt
import os

# Create images folder if it doesn't exist
os.makedirs("images", exist_ok=True)

# Better looking plots
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["font.size"] = 11
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["axes.labelsize"] = 12

#plt.rcParams applies consistent styling to every chart.
#os.makedirs() automatically creates the images folder, so savefig() never fails.

# %% [markdown]
# # Graph 1 — Movie vs TV Show Count
#
# ## Compare the amount of Movies and TV Shows available on Netflix.

# %%
content_count = df["content_type"].value_counts()

plt.figure(figsize=(8,5))

bars = plt.bar(
    content_count.index,
    content_count.values
)

plt.title("Netflix Content Distribution")
plt.xlabel("Content Type")
plt.ylabel("Number of Titles")
plt.grid(axis="y", linestyle="--", alpha=0.5)

# Value labels
for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height() + 50,
        int(bar.get_height()),
        ha="center",
        fontsize=11
    )

plt.tight_layout()
plt.savefig("images/movie_vs_tvshow_count.png", dpi=300)

plt.show()

# %% [markdown]
# ### Netflix offers significantly more Movies than TV Shows.
#
# This suggests Netflix has historically invested more in acquiring and producing movies, while TV Shows represent a smaller but strategically important segment for long-term viewer engagement.

# %% [markdown]
# # Graph 2 — Ratings Distribution
#
# ## Find the most common maturity ratings.

# %%
rating_count = df["rating"].value_counts().head(10)

plt.figure(figsize=(10,6))

bars = plt.bar(
    rating_count.index,
    rating_count.values
)

plt.title("Top 10 Netflix Content Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Titles")

plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.5)

for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height() + 30,
        int(bar.get_height()),
        ha="center",
        fontsize=10
    )

plt.tight_layout()
plt.savefig("images/ratings_distribution.png", dpi=300)

plt.show()

# %% [markdown]
# ## Netflix focuses heavily on mature audiences
#
# TV-MA is usually the largest category.
#
# TV-14 is the second largest.
#
# Kids ratings like TV-Y appear much less frequently.
#
# This indicates Netflix primarily targets teenage and adult audiences.

# %% [markdown]
# # Graph 3 — Top 10 Countries by Content
#
# ### Identify countries producing the most Netflix titles.

# %%
top_countries = (
    df["country"]
    .dropna()
    .str.split(", ")
    .explode()
    .value_counts()
    .head(10)
)

plt.figure(figsize=(12,6))

bars = plt.bar(
    top_countries.index,
    top_countries.values
)

plt.title("Top 10 Countries with Most Netflix Content")
plt.xlabel("Country")
plt.ylabel("Number of Titles")

plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.5)

for bar in bars:
    plt.text(
        bar.get_x()+bar.get_width()/2,
        bar.get_height()+20,
        int(bar.get_height()),
        ha="center",
        fontsize=10
    )

plt.tight_layout()
plt.savefig("images/top10_countries_content.png", dpi=300)

plt.show()

# %% [markdown]
# ### The United States leads Netflix content production
#
# United States contributes the largest share of content.
#
# India is among the top contributors.
#
# UK, Canada, and Japan also have significant representation.
#
# This reflects Netflix's strongest production markets.

# %% [markdown]
# # Graph 4 — Content Added by Year (Trend Analysis)
#
#
# ### Understand Netflix catalog growth over time.

# %%
content_year = (
    df["date_added"]
    .dt.year
    .value_counts()
    .sort_index()
)

plt.figure(figsize=(12,6))

plt.plot(
    content_year.index,
    content_year.values,
    marker="o",
    linewidth=2
)

plt.title("Netflix Content Added Over the Years")
plt.xlabel("Year Added")
plt.ylabel("Number of Titles")

plt.grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.savefig("images/content_added_by_year.png", dpi=300)

plt.show()

# %% [markdown]
# ### Netflix expanded rapidly after 2015
#
# Content additions accelerate around 2015–2019.
#
# Growth slows after the peak years.
#
# This aligns with Netflix's global expansion period.
